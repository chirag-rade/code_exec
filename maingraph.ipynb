# %%
from Models import testcaseGraph
from langchain_core.messages import (
    AIMessage,
    BaseMessage,
    ChatMessage,
    FunctionMessage,
    HumanMessage,
)

# %%
with open('Data/new_chirag/algorithm_problems_using_python__178__06_03_2024_15_46_55_1.ipynb', 'r') as file:
    convo= file.read()

input_message = {
    "chat_history": [],
    "messages": [HumanMessage((f"Conversation between AI Assistant and a human User: \n {convo}"))],
    "user_config": {},
}

result = testcaseGraph.run(input_message)
# Out:
# AGENT: {'main_node': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "code": "import numpy as np\\n\\ndef principal_component_analysis(X, num_components, standardize=True):\\n    try:\\n        # Input validation\\n        if not isinstance(X, np.ndarray):\\n            raise TypeError(\\"Input data must be a numpy.ndarray!\\")\\n        if len(X.shape) != 2:\\n            raise ValueError(\\"Input data must be a 2D array!\\")\\n        if not isinstance(num_components, int):\\n            raise TypeError(\\"Number of components must be an integer!\\")\\n        if num_components <= 0:\\n            raise ValueError(\\"Number of components must be greater than 0!\\")\\n        if num_components > X.shape[1]:\\n            raise ValueError(\\"Number of components must be less than or equal to number of features!\\")\\n\\n        # Standardizing the dataset (optional) and always centering\\n        mean = np.mean(X, axis=0)\\n        if standardize:\\n            std_dev = np.std(X, axis=0, ddof=1)\\n            X = (X - mean) / std_dev\\n        else:\\n            X = X - mean\\n\\n        # Calculate the covariance matrix\\n        covariance_matrix = np.cov(X, rowvar=False) # rowvar=False means that columns represent variables\\n\\n\\n        # Compute the eigenvalues and eigenvectors of the covariance matrix\\n        eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)\\n        if np.iscomplexobj(eigenvalues):\\n            raise ValueError(\\"Complex eigenvalues encountered. PCA might not be suitable for this dataset!\\")\\n\\n        # Sort eigenvectors by their associated eigenvalues in descending order\\n        idx = np.argsort(eigenvalues)[::-1]\\n        eigenvalues = eigenvalues[idx]\\n        # Align eigenvectors with sorted eigenvalues\\n        eigenvectors = eigenvectors[:, idx]\\n\\n        # Select the first num_components eigenvectors\\n        eigenvectors = eigenvectors[:, :num_components]\\n\\n        # Transform the original matrix by projecting data onto principal components\\n        X_pca = np.dot(X, eigenvectors)\\n\\n        total_variance = np.sum(eigenvalues)\\n        explained_variance = eigenvalues[:num_components] / total_variance\\n\\n        return X_pca, explained_variance\\n\\n    except TypeError as te:\\n        print(f\\"TypeError: {te}\\")\\n        return None\\n    except ValueError as ve:\\n        print(f\\"ValueError: {ve}\\")\\n        return None\\n\\n# Example Usage\\nnp.random.seed(42)\\nX = np.random.randn(500, 6)  # Simulated data\\n\\n# Specify the number of components\\nnum_components = 2\\n\\n# Perform PCA with standardization and get the transformed data and variance explained\\ntransformed_data, explained_variance = principal_component_analysis(X, num_components, standardize=True)\\n\\nif transformed_data is not None and explained_variance is not None:\\n    print(\\"Original data shape: \\", X.shape)\\n    print(\\"Transformed data shape: \\", transformed_data.shape)\\n    print(\\"Variance explained by each principal component: \\", explained_variance)\\nelse:\\n    print(\\"PCA computation failed.\\")"\n}', 'name': 'python_repl'}}, response_metadata={'token_usage': {'completion_tokens': 713, 'prompt_tokens': 3953, 'total_tokens': 4666}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_729ea513f7', 'finish_reason': 'function_call', 'logprobs': None}, id='run-ee8feacd-73b5-4bc7-8c05-6645803d4ac1-0')], 'sender': 'main_node'}}
# I am calling the function python_repl with the following arguments: { "code": "import numpy as np\n\ndef
# principal_component_analysis(X, num_components, standardize=True):\n    try:\n        # Input validation\n
# if not isinstance(X, np.ndarray):\n            raise TypeError("Input data must be a numpy.ndarray!")\n        if
# len(X.shape) != 2:\n            raise ValueError("Input data must be a 2D array!")\n        if not
# isinstance(num_components, int):\n            raise TypeError("Number of components must be an integer!")\n
# if num_components <= 0:\n            raise ValueError("Number of components must be greater than 0!")\n        if
# num_components > X.shape[1]:\n            raise ValueError("Number of components must be less than or equal to
# number of features!")\n\n        # Standardizing the dataset (optional) and always centering\n        mean =
# np.mean(X, axis=0)\n        if standardize:\n            std_dev = np.std(X, axis=0, ddof=1)\n            X = (X -
# mean) / std_dev\n        else:\n            X = X - mean\n\n        # Calculate the covariance matrix\n
# covariance_matrix = np.cov(X, rowvar=False) # rowvar=False means that columns represent variables\n\n\n        #
# Compute the eigenvalues and eigenvectors of the covariance matrix\n        eigenvalues, eigenvectors =
# np.linalg.eig(covariance_matrix)\n        if np.iscomplexobj(eigenvalues):\n            raise ValueError("Complex
# eigenvalues encountered. PCA might not be suitable for this dataset!")\n\n        # Sort eigenvectors by their
# associated eigenvalues in descending order\n        idx = np.argsort(eigenvalues)[::-1]\n        eigenvalues =
# eigenvalues[idx]\n        # Align eigenvectors with sorted eigenvalues\n        eigenvectors = eigenvectors[:,
# idx]\n\n        # Select the first num_components eigenvectors\n        eigenvectors = eigenvectors[:,
# :num_components]\n\n        # Transform the original matrix by projecting data onto principal components\n
# X_pca = np.dot(X, eigenvectors)\n\n        total_variance = np.sum(eigenvalues)\n        explained_variance =
# eigenvalues[:num_components] / total_variance\n\n        return X_pca, explained_variance\n\n    except TypeError
# as te:\n        print(f"TypeError: {te}")\n        return None\n    except ValueError as ve:\n
# print(f"ValueError: {ve}")\n        return None\n\n# Example Usage\nnp.random.seed(42)\nX = np.random.randn(500, 6)
# # Simulated data\n\n# Specify the number of components\nnum_components = 2\n\n# Perform PCA with standardization
# and get the transformed data and variance explained\ntransformed_data, explained_variance =
# principal_component_analysis(X, num_components, standardize=True)\n\nif transformed_data is not None and
# explained_variance is not None:\n    print("Original data shape: ", X.shape)\n    print("Transformed data shape: ",
# transformed_data.shape)\n    print("Variance explained by each principal component: ", explained_variance)\nelse:\n
# print("PCA computation failed.")" }
# AGENT: {'call_tool': {'messages': [FunctionMessage(content='python_repl response: Successfully executed:\n```python\nimport numpy as np\n\ndef principal_component_analysis(X, num_components, standardize=True):\n    try:\n        # Input validation\n        if not isinstance(X, np.ndarray):\n            raise TypeError("Input data must be a numpy.ndarray!")\n        if len(X.shape) != 2:\n            raise ValueError("Input data must be a 2D array!")\n        if not isinstance(num_components, int):\n            raise TypeError("Number of components must be an integer!")\n        if num_components <= 0:\n            raise ValueError("Number of components must be greater than 0!")\n        if num_components > X.shape[1]:\n            raise ValueError("Number of components must be less than or equal to number of features!")\n\n        # Standardizing the dataset (optional) and always centering\n        mean = np.mean(X, axis=0)\n        if standardize:\n            std_dev = np.std(X, axis=0, ddof=1)\n            X = (X - mean) / std_dev\n        else:\n            X = X - mean\n\n        # Calculate the covariance matrix\n        covariance_matrix = np.cov(X, rowvar=False) # rowvar=False means that columns represent variables\n\n\n        # Compute the eigenvalues and eigenvectors of the covariance matrix\n        eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)\n        if np.iscomplexobj(eigenvalues):\n            raise ValueError("Complex eigenvalues encountered. PCA might not be suitable for this dataset!")\n\n        # Sort eigenvectors by their associated eigenvalues in descending order\n        idx = np.argsort(eigenvalues)[::-1]\n        eigenvalues = eigenvalues[idx]\n        # Align eigenvectors with sorted eigenvalues\n        eigenvectors = eigenvectors[:, idx]\n\n        # Select the first num_components eigenvectors\n        eigenvectors = eigenvectors[:, :num_components]\n\n        # Transform the original matrix by projecting data onto principal components\n        X_pca = np.dot(X, eigenvectors)\n\n        total_variance = np.sum(eigenvalues)\n        explained_variance = eigenvalues[:num_components] / total_variance\n\n        return X_pca, explained_variance\n\n    except TypeError as te:\n        print(f"TypeError: {te}")\n        return None\n    except ValueError as ve:\n        print(f"ValueError: {ve}")\n        return None\n\n# Example Usage\nnp.random.seed(42)\nX = np.random.randn(500, 6)  # Simulated data\n\n# Specify the number of components\nnum_components = 2\n\n# Perform PCA with standardization and get the transformed data and variance explained\ntransformed_data, explained_variance = principal_component_analysis(X, num_components, standardize=True)\n\nif transformed_data is not None and explained_variance is not None:\n    print("Original data shape: ", X.shape)\n    print("Transformed data shape: ", transformed_data.shape)\n    print("Variance explained by each principal component: ", explained_variance)\nelse:\n    print("PCA computation failed.")\n```\nStdout: Original data shape:  (500, 6)\nTransformed data shape:  (500, 2)\nVariance explained by each principal component:  [0.19109067 0.18551673]\n', name='python_repl')]}}
# python_repl response: Successfully executed:
#
#
#  import numpy as np
#
#  def principal_component_analysis(X, num_components, standardize=True):
#      try:
#          # Input validation
#          if not isinstance(X, np.ndarray):
#              raise TypeError("Input data must be a numpy.ndarray!")
#          if len(X.shape) != 2:
#              raise ValueError("Input data must be a 2D array!")
#          if not isinstance(num_components, int):
#              raise TypeError("Number of components must be an integer!")
#          if num_components <= 0:
#              raise ValueError("Number of components must be greater than 0!")
#          if num_components > X.shape[1]:
#              raise ValueError("Number of components must be less than or equal to number of features!")
#
#          # Standardizing the dataset (optional) and always centering
#          mean = np.mean(X, axis=0)
#          if standardize:
#              std_dev = np.std(X, axis=0, ddof=1)
#              X = (X - mean) / std_dev
#          else:
#              X = X - mean
#
#          # Calculate the covariance matrix
#          covariance_matrix = np.cov(X, rowvar=False) # rowvar=False means that columns represent variables
#
#
#          # Compute the eigenvalues and eigenvectors of the covariance matrix
#          eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)
#          if np.iscomplexobj(eigenvalues):
#              raise ValueError("Complex eigenvalues encountered. PCA might not be suitable for this dataset!")
#
#          # Sort eigenvectors by their associated eigenvalues in descending order
#          idx = np.argsort(eigenvalues)[::-1]
#          eigenvalues = eigenvalues[idx]
#          # Align eigenvectors with sorted eigenvalues
#          eigenvectors = eigenvectors[:, idx]
#
#          # Select the first num_components eigenvectors
#          eigenvectors = eigenvectors[:, :num_components]
#
#          # Transform the original matrix by projecting data onto principal components
#          X_pca = np.dot(X, eigenvectors)
#
#          total_variance = np.sum(eigenvalues)
#          explained_variance = eigenvalues[:num_components] / total_variance
#
#          return X_pca, explained_variance
#
#      except TypeError as te:
#          print(f"TypeError: {te}")
#          return None
#      except ValueError as ve:
#          print(f"ValueError: {ve}")
#          return None
#
#  # Example Usage
#  np.random.seed(42)
#  X = np.random.randn(500, 6)  # Simulated data
#
#  # Specify the number of components
#  num_components = 2
#
#  # Perform PCA with standardization and get the transformed data and variance explained
#  transformed_data, explained_variance = principal_component_analysis(X, num_components, standardize=True)
#
#  if transformed_data is not None and explained_variance is not None:
#      print("Original data shape: ", X.shape)
#      print("Transformed data shape: ", transformed_data.shape)
#      print("Variance explained by each principal component: ", explained_variance)
#  else:
#      print("PCA computation failed.")
#
#
# Stdout: Original data shape:  (500, 6) Transformed data shape:  (500, 2) Variance explained by each principal
# component:  [0.19109067 0.18551673]
# AGENT: {'main_node': {'messages': [AIMessage(content='{\n  "scratchpad": "The code provided for implementing PCA is correct and runs without any errors. It successfully reduces the dimensionality of the dataset and provides the explained variance for each principal component. The use of NumPy ensures that the implementation is efficient. Input validation and error handling are included, which is good practice. The code is well-commented, making it readable and easy to understand.\\n\\nHowever, there are a few areas that could be improved:\\n1. The function does not handle the case where the dataset might contain NaN or infinite values, which could lead to unexpected results.\\n2. Instead of printing error messages, it might be better to raise exceptions, allowing the calling code to handle them appropriately.\\n\\nThe code fulfills the user’s request and provides a complete implementation of PCA from scratch in Python, including data standardization, computation of the covariance matrix, eigenvalue decomposition, and projection of the original dataset onto the new feature space. Thus, the user request is fully satisfied.",\n  "issues": [\n    {\n      "cell_position": 4,\n      "what": "Missing handling of NaN or infinite values in the dataset.",\n      "why": "NaN or infinite values in the dataset can lead to incorrect calculations and unexpected results during PCA.",\n      "where": "In the `principal_component_analysis` function, before standardizing the dataset.",\n      "severity": "Low",\n      "fix": "Add checks to handle or remove NaN or infinite values in the dataset before proceeding with PCA."\n    },\n    {\n      "cell_position": 4,\n      "what": "Error handling could be improved by raising exceptions instead of printing error messages.",\n      "why": "Raising exceptions allows the calling code to handle errors appropriately, making the function more versatile and robust.",\n      "where": "In the `except` blocks of the `principal_component_analysis` function.",\n      "severity": "Low",\n      "fix": "Replace `print` statements with `raise` statements in the `except` blocks."\n    }\n  ],\n  "scoring_explanation": "The code is correct, efficient, and follows best practices. It is highly readable and fulfills the user’s request completely. The issues identified are minor and do not significantly impact the overall quality of the code. Thus, the scoring is affected minimally.",\n  "score": 4\n}', response_metadata={'token_usage': {'completion_tokens': 487, 'prompt_tokens': 5356, 'total_tokens': 5843}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_729ea513f7', 'finish_reason': 'stop', 'logprobs': None}, id='run-2e3e4a46-dd83-4373-8496-004d549672af-0')], 'sender': 'main_node'}}
# {'scratchpad': 'The code provided for implementing PCA is correct and runs without any errors. It successfully
# reduces the dimensionality of the dataset and provides the explained variance for each principal component. The use
# of NumPy ensures that the implementation is efficient. Input validation and error handling are included, which is
# good practice. The code is well-commented, making it readable and easy to understand.\n\nHowever, there are a few
# areas that could be improved:\n1. The function does not handle the case where the dataset might contain NaN or
# infinite values, which could lead to unexpected results.\n2. Instead of printing error messages, it might be better
# to raise exceptions, allowing the calling code to handle them appropriately.\n\nThe code fulfills the user’s
# request and provides a complete implementation of PCA from scratch in Python, including data standardization,
# computation of the covariance matrix, eigenvalue decomposition, and projection of the original dataset onto the new
# feature space. Thus, the user request is fully satisfied.', 'issues': [{'cell_position': 4, 'what': 'Missing
# handling of NaN or infinite values in the dataset.', 'why': 'NaN or infinite values in the dataset can lead to
# incorrect calculations and unexpected results during PCA.', 'where': 'In the principal_component_analysis function,
# before standardizing the dataset.', 'severity': 'Low', 'fix': 'Add checks to handle or remove NaN or infinite
# values in the dataset before proceeding with PCA.'}, {'cell_position': 4, 'what': 'Error handling could be improved
# by raising exceptions instead of printing error messages.', 'why': 'Raising exceptions allows the calling code to
# handle errors appropriately, making the function more versatile and robust.', 'where': 'In the except blocks of the
# principal_component_analysis function.', 'severity': 'Low', 'fix': 'Replace print statements with raise statements
# in the except blocks.'}], 'scoring_explanation': 'The code is correct, efficient, and follows best practices. It is
# highly readable and fulfills the user’s request completely. The issues identified are minor and do not
# significantly impact the overall quality of the code. Thus, the scoring is affected minimally.', 'score': 4}

# %%
from IPython.display import display, HTML
import json

def pretty_print_html(data):
    # Convert the dictionary to a JSON string with indentation for readability
    pretty_data = json.dumps(data, indent=4)
    
    # Prepare HTML string with color styling
    html_data = '<pre style="line-height: 1.35;">'
    for line in pretty_data.splitlines():
        if ':' in line:
            key, value = line.split(':', 1)
            key = f'<span style="color: blue;">{key}</span>'
            if value.strip().startswith('"'):
                value = f'<span style="color: green;">{value}</span>'
            elif value.strip().isdigit():
                value = f'<span style="color: red;">{value}</span>'
            html_data += f"{key}:{value}\n"
        else:
            html_data += f'<span style="color: black;">{line}</span>\n'
    html_data += '</pre>'
    
    display(HTML(html_data))

content = json.loads(result)
pretty_print_html(content)
# Out:
# <pre style="line-height: 1.35;"><span style="color: black;">{</span>
# <span style="color: blue;">    "scratchpad"</span>:<span style="color: green;"> "The code provided for implementing PCA is correct and runs without any errors. It successfully reduces the dimensionality of the dataset and provides the explained variance for each principal component. The use of NumPy ensures that the implementation is efficient. Input validation and error handling are included, which is good practice. The code is well-commented, making it readable and easy to understand.\n\nHowever, there are a few areas that could be improved:\n1. The function does not handle the case where the dataset might contain NaN or infinite values, which could lead to unexpected results.\n2. Instead of printing error messages, it might be better to raise exceptions, allowing the calling code to handle them appropriately.\n\nThe code fulfills the user\u2019s request and provides a complete implementation of PCA from scratch in Python, including data standardization, computation of the covariance matrix, eigenvalue decomposition, and projection of the original dataset onto the new feature space. Thus, the user request is fully satisfied.",</span>
# <span style="color: blue;">    "issues"</span>: [
# <span style="color: black;">        {</span>
# <span style="color: blue;">            "cell_position"</span>: 4,
# <span style="color: blue;">            "what"</span>:<span style="color: green;"> "Missing handling of NaN or infinite values in the dataset.",</span>
# <span style="color: blue;">            "why"</span>:<span style="color: green;"> "NaN or infinite values in the dataset can lead to incorrect calculations and unexpected results during PCA.",</span>
# <span style="color: blue;">            "where"</span>:<span style="color: green;"> "In the `principal_component_analysis` function, before standardizing the dataset.",</span>
# <span style="color: blue;">            "severity"</span>:<span style="color: green;"> "Low",</span>
# <span style="color: blue;">            "fix"</span>:<span style="color: green;"> "Add checks to handle or remove NaN or infinite values in the dataset before proceeding with PCA."</span>
# <span style="color: black;">        },</span>
# <span style="color: black;">        {</span>
# <span style="color: blue;">            "cell_position"</span>: 4,
# <span style="color: blue;">            "what"</span>:<span style="color: green;"> "Error handling could be improved by raising exceptions instead of printing error messages.",</span>
# <span style="color: blue;">            "why"</span>:<span style="color: green;"> "Raising exceptions allows the calling code to handle errors appropriately, making the function more versatile and robust.",</span>
# <span style="color: blue;">            "where"</span>:<span style="color: green;"> "In the `except` blocks of the `principal_component_analysis` function.",</span>
# <span style="color: blue;">            "severity"</span>:<span style="color: green;"> "Low",</span>
# <span style="color: blue;">            "fix"</span>:<span style="color: green;"> "Replace `print` statements with `raise` statements in the `except` blocks."</span>
# <span style="color: black;">        }</span>
# <span style="color: black;">    ],</span>
# <span style="color: blue;">    "scoring_explanation"</span>:<span style="color: green;"> "The code is correct, efficient, and follows best practices. It is highly readable and fulfills the user\u2019s request completely. The issues identified are minor and do not significantly impact the overall quality of the code. Thus, the scoring is affected minimally.",</span>
# <span style="color: blue;">    "score"</span>:<span style="color: red;"> 4</span>
# <span style="color: black;">}</span>
# </pre>
